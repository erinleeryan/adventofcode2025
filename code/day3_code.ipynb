# %%
import data_parsing 
import math

input_data = '../data/day3_example.txt'


def find_largest_combo(inputdigits:str):
    digits = list(range(9,0, -1))
    input_split = [int(x) for x in inputdigits]

    print (inputsplit)
    return



find_largest_combo('12345678')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import data_parsing
#       2 import math
#       4 input_data = '../data/day3_example.txt'
#
# ModuleNotFoundError: No module named 'data_parsing'
